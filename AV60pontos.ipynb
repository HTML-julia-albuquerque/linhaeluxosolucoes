# %%
print('================================================================================================================================================================')
print('                                                                  LISTA DE ROUPAS                                                                               ')
print('================================================================================================================================================================')

roupas_dict = {'blusa de frio': ('19,99', 'cashmere'),
               'blusa de calor': ('17,00', 'algodão'),
               'calça jeans':('30,00', 'jeans'),
               'short': ('15,00', 'jeans'),
               'calca legging':('20,00', 'Poliéster'),
               'luva': ('15,00', 'algodão'),
               'gorro': ('15,00', 'algodão'),
               'chapéu': ('10,00', 'algodão')}

for produto in roupas_dict.keys():
    print(produto)
produto = str(input('Digite o produto que você deseja visualizar: ')).lower()
print(roupas_dict[produto])
if produto not in roupas_dict:
    print("Perdão, ainda não temos esse produto!")
# Out:
# ================================================================================================================================================================
#                                                                   LISTA DE ROUPAS
# =====================================================================================================================================
# blusa de frio
# blusa de calor
# calça jeans
# short
# calca legging
# luva
# gorro
# chapéu
# Digite o produto que você deseja visualizar: Blusa de frio
# ('19,99', 'cashmere')
